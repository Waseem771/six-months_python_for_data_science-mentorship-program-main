# %%
import pandas as pd

# Example datasets for data merging
# Dataset 1: Pakistani Individuals
data1 = {
    'id': [1, 2, 3],
    'name': ['Ahmed', 'Fatima', 'Ali'],
    'age': [28, 32, 24]
}
df1 = pd.DataFrame(data1)
df1.head()
# Out:
#    id    name  age
# 0   1   Ahmed   28
# 1   2  Fatima   32
# 2   3     Ali   24

# %%
# Dataset 2: Additional Information
data2 = {
    'id': [1, 2, 3],
    'city': ['Karachi', 'Lahore', 'Islamabad'],
    'occupation': ['Engineer', 'Doctor', 'Teacher']
}
df2 = pd.DataFrame(data2)
df2.head()
# Out:
#    id       city occupation
# 0   1    Karachi   Engineer
# 1   2     Lahore     Doctor
# 2   3  Islamabad    Teacher

# %%
# Merging DataFrames on 'id'
merged_df = pd.merge(df1, df2, on='id', how='inner')
merged_df.head()
# Out:
#    id    name  age       city occupation
# 0   1   Ahmed   28    Karachi   Engineer
# 1   2  Fatima   32     Lahore     Doctor
# 2   3     Ali   24  Islamabad    Teacher

# %%
import pandas as pd

# Example datasets for Pakistani context
# Dataset 1 - Pakistani Names and Ages
data1 = {'Name': ['Ahmed', 'Fatima', 'Ali'], 'Age': [28, 32, 24]}
# Dataset 2 - More Pakistani Names and Ages
data2 = {'Name': ['Sara', 'Usman', 'Aisha'], 'Age': [29, 35, 27]}
# Dataset 3 - Cities and Provinces in Pakistan
data3 = {'City': ['Karachi', 'Lahore', 'Islamabad'], 'Province': ['Sindh', 'Punjab', 'Islamabad']}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
df3 = pd.DataFrame(data3)

# Concatenating Rows
concatenated_rows = pd.concat([df1, df2])

# Concatenating Columns
# Note: For a meaningful column-wise concatenation, dataframes should have the same number of rows.
concatenated_columns = pd.concat([df1, df3], axis=1)
print(concatenated_rows)
print(";;;;;;;;;;;;;;;;;;;;;;;;;;;;;;")
concatenated_columns
# Out:
#      Name  Age
# 0   Ahmed   28
# 1  Fatima   32
# 2     Ali   24
# 0    Sara   29
# 1   Usman   35
# 2   Aisha   27
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
#      Name  Age       City   Province
# 0   Ahmed   28    Karachi      Sindh
# 1  Fatima   32     Lahore     Punjab
# 2     Ali   24  Islamabad  Islamabad

# %%
# import libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler

# %%
# make an example dataset
df = {
    'age': [25,30,35,40,45],
    'height': [165,170,175,180,185],
    'weight': [55,60,65,70,75]
}

# conver this data to pandas datafram
df = pd.DataFrame(df)
df.head()
# Out:
#    age  height  weight
# 0   25     165      55
# 1   30     170      60
# 2   35     175      65
# 3   40     180      70
# 4   45     185      75

# %%
# import the scalar
scalar = StandardScaler()

# fit the scalar on data
scaled_df = scalar.fit_transform(df)
scaled_df
# convert this data into a pandas dataframe
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df.head()
# Out:
#         age    height    weight
# 0 -1.414214 -1.414214 -1.414214
# 1 -0.707107 -0.707107 -0.707107
# 2  0.000000  0.000000  0.000000
# 3  0.707107  0.707107  0.707107
# 4  1.414214  1.414214  1.414214

# %% [markdown]
# ## Min Max Scaller

# %%
# import the scalar
scalar = MinMaxScaler()
# fit the scalar on data
scaled_df = scalar.fit_transform(df)
scaled_df
# convert this data into a pandas dataframe
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df.head()
# Out:
#     age  height  weight
# 0  0.00    0.00    0.00
# 1  0.25    0.25    0.25
# 2  0.50    0.50    0.50
# 3  0.75    0.75    0.75
# 4  1.00    1.00    1.00

# %% [markdown]
# ## Max ABS scalar

# %%
# import the scalar
scalar = MaxAbsScaler()

# fit the scalar on data
scaled_df = scalar.fit_transform(df)
scaled_df
# convert this data into a pandas dataframe
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df
# Out:
#         age    height    weight
# 0  0.555556  0.891892  0.733333
# 1  0.666667  0.918919  0.800000
# 2  0.777778  0.945946  0.866667
# 3  0.888889  0.972973  0.933333
# 4  1.000000  1.000000  1.000000

# %% [markdown]
# ## Robust Scaller

# %%
from sklearn.preprocessing import RobustScaler

# import the scalar
scalar = RobustScaler()

# fit the scalar on data
scaled_df = scalar.fit_transform(df)
scaled_df
# convert this data into a pandas dataframe
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df.head()
# Out:
#    age  height  weight
# 0 -1.0    -1.0    -1.0
# 1 -0.5    -0.5    -0.5
# 2  0.0     0.0     0.0
# 3  0.5     0.5     0.5
# 4  1.0     1.0     1.0

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ghg\miniconda3\envs\python_ml\lib\site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\ghg\miniconda3\envs\python_ml\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\ghg\miniconda3\envs\python_ml\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ghg\miniconda3\envs\python_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ghg\miniconda3\envs\python_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ghg\miniconda3\envs\python_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ghg\miniconda3\envs\python_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ghg\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\ghg\miniconda3\envs\python_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ghg\miniconda3\envs\python_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ghg\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ghg\miniconda3\envs\python_ml\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ghg\miniconda3\envs\python_ml\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ghg\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.6 kB 187.9 kB/s eta 0:00:02
#    ---- ---------------------------------- 30.7/294.6 kB 187.9 kB/s eta 0:00:02
#    ----- --------------------------------- 41.0/294.6 kB 178.6 kB/s eta 0:00:02
#    --------- ----------------------------- 71.7/294.6 kB 245.8 kB/s eta 0:00:01
#    -------------- ----------------------- 112.6/294.6 kB 344.8 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.6 kB 405.9 kB/s eta 0:00:01
#    ------------------------- ------------ 194.6/294.6 kB 471.4 kB/s eta 0:00:01
#    --------------------------------- ---- 256.0/294.6 kB 561.1 kB/s eta 0:00:01
#    -------------------------------------- 294.6/294.6 kB 606.3 kB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
import seaborn as sns
sns.scatterplot(x='age', y='height', data=df)
# Out:
# <Axes: xlabel='age', ylabel='height'>
